# %% [markdown]
# <a href="https://colab.research.google.com/github/uginm102/ARMS/blob/master/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('https://raw.githubusercontent.com/uginm102/MCSC-MUK/main/MCS7103-MachineLearning/CubanDataset.csv')

data.value_counts()
# Out:
# id    age  menarche  menopause  agefirst  children  breastfeeding  nrelbc         biopsies  hyperplasia  race   year    imc   weight  exercise  alcohol  tobacco  allergies   emotional  depressive  histologicalclass  birads  cancer
# 1     50   11        No         No        0         No             Mother         1.0       Yes          White  2011.0  27.6  83.4    No        Yes      Yes      Rhinitis    Sad        Yes         3.0                3A      Yes       1
# 798   61   11        46         25        1         2 months       Sister         1.0       No           White  2015.0  24.2  68.0    No        Yes      Yes      Medicines   Joy        No          3.0                4B      Yes       1
# 778   27   11        No         No        0         No             No             3.0       Yes          White  2016.0  28.7  84.2    Diary     No       No       Laryngitis  Joy        No          3.0                4B      Yes       1
# ...
